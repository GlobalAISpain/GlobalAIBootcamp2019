# %% [markdown]
# <H1>Es necesario trabajar en un entorno Python 3.6<H1>

# %%
# !pip install tweepy markovify
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting markovify
#   Downloading https://files.pythonhosted.org/packages/99/b7/a5cf39283f08c8013623dbcf67063b0215942ae464fc864eca1434d050e1/markovify-0.7.2.tar.gz
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tweepy) (1.3.0)
# Collecting PySocks>=1.5.7
#   Downloading https://files.pythonhosted.org/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tweepy) (2.14.2)
# Requirement already satisfied: six>=1.10.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from tweepy) (1.11.0)
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 3.9MB/s eta 0:00:01
# Requirement already satisfied: oauthlib>=3.0.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Building wheels for collected packages: markovify
#   Building wheel for markovify (setup.py) ... done
#   Created wheel for markovify: filename=markovify-0.7.2-cp35-none-any.whl size=10398 sha256=e7d7241eeef6f09b0ccd2e6aa7479eba1685123337e8a0ef41cdb1ecfc7eb7df
#   Stored in directory: /home/nbuser/.cache/pip/wheels/0c/19/38/b901adb8ab0721a6c8c86f468e48b22f3ecf08560e6aeb99fa
# Successfully built markovify
# Installing collected packages: PySocks, tweepy, unidecode, markovify
# Successfully installed PySocks-1.7.1 markovify-0.7.2 tweepy-3.8.0 unidecode-1.1.1

# %%
import json
import tweepy

CONSUMER_API_KEY = "kHg5iXdpBwnhcS7KkhcjxqGct"
CONSUMER_API_SECRET_KEY = "dV5rbUzvdCbYsi7AfixmpIZukHo8sVo3By9DaRQ0OHO9jqF0gB"
ACCESS_TOKEN = "1203743902072791041-75QEVDoFWwgjLoaE4ZP2K0dKvurzhP"
ACCESS_TOKEN_SECRET = "z5NSTB6AU0RPFjioe7TgjjMGlHWLIEef77Ikx6stWJUHL"

auth = tweepy.OAuthHandler(CONSUMER_API_KEY, CONSUMER_API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(
    auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True
)

# %%
user_id = "GaibSpain"
count = 200
user_tweets = api.user_timeline(screen_name=user_id, count=count, tweet_mode="extended")

# %%
tweet_corpus = []
for tweet in user_tweets:
    tweet_corpus.append(tweet.full_text)
tweets_text = ". ".join(tweet_corpus)

# %%
tweets_text
# Out:
# 'Esto mola! @FMSepulveda @robtejero https://t.co/nIGab5FZCc. Y si usamos la inteligencia artificial para cosas malas? @robtejero @FMSepulveda https://t.co/jE4marSSJv. Arrancamos la gran sesión de mis colegas @robtejero y  @FMSepulveda sobre Machine Learning y Seguridad .... de combate! https://t.co/DQDR5hI3A4. 📢 Ultima sesión del dia en el Track 2 a las 15:45 "Responsible AI" por la gran @sara_sanluis 👏👏👏#GlobalAIBootcamp 2019 #Madrid Mas info en https://t.co/p3SIeSyz1m https://t.co/vEOZWoWeK5. RT @JavierPallo: Debo reconocer que el momento en que me pillaste fue el bueno. 😀😀😀😀 https://t.co/ecYxzvF1yv. 📢 Para finalizar hoy, en el Track 1 a las 15:45 "Machine Learning de combate!!" por el maestro @FMSepulveda y otros de nuestros MVPs @robtejero 👏👏👏#GlobalAIBootcamp 2019 #Madrid. Va a haber … hondonada de …. #ML Mas info \uf0e8 https://t.co/p3SIeSQ9SU https://t.co/2lunGzJSp1. RT @RechOneSix: Demo de #PoliTweets con Miguel Saenz y @ericmcmc1 en #GlobalAIBootCamp @GaibSpain. Good luck mate!!!  👍👍👍 https://t.co/cVhibagYH5. RT @calelltek: #Politweets #GlobalAIBootcamp https://t.co/HyE2yu4THd. RT @ambynet: ¿Eres hombre y estás disfrutando del #GlobalAIBootcamp #Madrid @GaibSpain? Si estás interesado en conocer cómo ayudar en temas…. RT @calelltek: #Politweets Procesamiento de las palabras #GlobalAIBootcamp https://t.co/vPjXzL945C. RT @calelltek: #Hyper-#Parameters #Politweets #GlobalAIBootcamp https://t.co/VvzoHrX2zq. RT @Aless_Gragera: Rendimiento servidor inteligencia artificial #GlobalAIBootcamp @GaibSpain @GlobalAIBC https://t.co/nXCyKxYPof. 📢 En el otro lado del ring, en el Track 2 a las 14:45 "Mejorando el rendimiento de un servidor con Inteligencia Artificial" por otro de nuestros MVPs @enriquecatala y @pausempere  👏👏👏#GlobalAIBootcamp 2019 #Madrid. Mas info en https://t.co/p3SIeSQ9SU https://t.co/GpWBYM9CWT. 📢 Después de la comida en el Track 1 a las 14:45 "R y Python con Power BI, la ciencia y el análisis de datos, juntos” por otro MVP!!!! @ambynet 👏👏👏 #GlobalAIBootcamp 2019 #Madrid Mas info \uf0e8 https://t.co/p3SIeSQ9SU https://t.co/TrToBdpCVM. RT @dasc_IT: ¿Qué piensan nuestros políticos? AI for Twitter. #GlobalAIBootcamp @ericmcmc1 https://t.co/n7xKRjZtdR. RT @RechOneSix: Cambiando palabras a vectores con Miguel Saenz #GlobalAIBootcamp @GaibSpain https://t.co/bUB8pfuL3P. RT @ambynet: Disfrutando de las reflexiones, consejos y excelentes recursos presentados por @tgranell en #GlobalAIBootcamp #Madrid #DataPla…. RT @rfcm83: RT ambynet: Modelado, modelado y modelado para MSPowerBI #DataCleansing #DAX #DataMining #QnA #Bot #GlobalAIBootcamp  KabelSist…. RT @sara_sanluis: ¿En qué piensan nuestros políticos?🤔 @ericmcmc1 y Miguel nos cuentan cómo descubrirlo usando NLP en el #GlobalAIBootcamp.…. RT @JaimeAbad9: Hoy estoy en el Gobal AI Community en @MicrosoftES #GlobalAIBootcamp https://t.co/1RSyzE0tBI. RT @calelltek: Proceso desarrollo #Pipeline #GlobalAIBootcamp https://t.co/sswkSIVfuE. RT @everis: Llega #GlobalAIBootcamp al #everisLivingLab. Un evento mundial en el que distintas comunidades se unen para compartir conocimie…. RT @calelltek: Adelantando herramientas de trabajo #AzureDevOps #GlobalAIBootcamp https://t.co/v2dZ3T8Ins. RT @calelltek: Cuantización #CoralDevBoard #GlobalAIBootcamp https://t.co/YJB3ZghLyT. RT @solidqes: 📸 Nuestros compañeros @miguelEgea , @pausempere y @enriquecatala , speakers en el #GlobalAIbootcamp 2019 de #Madrid :) @GaibS…. RT @ambynet: Me ha gustado mucho la charla y las demos presentadas por @carloscalvo_es en #GlobalAIBootcamp #Madrid @MicrosoftES #R #Machin…. RT @RechOneSix: Politweets con @ericmcmc1 y Miguel Saenz #GlobalAIBootcamp @GaibSpain https://t.co/blGdHl0BZu. RT @iCanizares: RT ambynet: Modelado, modelado y modelado para MSPowerBI #DataCleansing #DAX #DataMining #QnA #Bot #GlobalAIBootcamp  Kabel…. Cuartas sesiones del día en el #GlobalAIBootcamp. Lo q os estáis perdiendo!!!! https://t.co/hHPUQZozUz. RT @hboelman: Watching the first #globalaibootcamp online https://t.co/seuZAJbtXz.  ...

# %%
import re


def replace_URLs(string, new_URL):
    """Replaces all URLs in a string with a custom URL."""
    modified_string = re.sub(
        "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\), ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+",
        " " + new_URL + " ",
        string,
    )
    return modified_string

# %%
phishing_link = "https://urlzs.com/u8ZB"

# %%
processed_tweets_text = replace_URLs(tweets_text, phishing_link)

# %%
processed_tweets_text
# Out:
# 'Esto mola! @FMSepulveda @robtejero  https://urlzs.com/u8ZB ón de mis colegas @robtejero y  @FMSepulveda sobre Machine Learning y Seguridad .... de combate!  https://urlzs.com/u8ZB 📢 Ultima sesión del dia en el Track 2 a las 15:45 "Responsible AI" por la gran @sara_sanluis 👏👏👏#GlobalAIBootcamp 2019 #Madrid Mas info en  https://urlzs.com/u8ZB 😀😀😀😀  https://urlzs.com/u8ZB 📢 Para finalizar hoy, en el Track 1 a las 15:45 "Machine Learning de combate!!" por el maestro @FMSepulveda y otros de nuestros MVPs @robtejero 👏👏👏#GlobalAIBootcamp 2019 #Madrid. Va a haber … hondonada de …. #ML Mas info \uf0e8  https://urlzs.com/u8ZB #PoliTweets con Miguel Saenz y @ericmcmc1 en #GlobalAIBootCamp @GaibSpain. Good luck mate!!!  👍👍👍  https://urlzs.com/u8ZB #Politweets #GlobalAIBootcamp  https://urlzs.com/u8ZB ¿Eres hombre y estás disfrutando del #GlobalAIBootcamp #Madrid @GaibSpain? Si estás interesado en conocer cómo ayudar en temas…. RT @calelltek: #Politweets Procesamiento de las palabras #GlobalAIBootcamp  https://urlzs.com/u8ZB #Hyper-#Parameters #Politweets #GlobalAIBootcamp  https://urlzs.com/u8ZB #GlobalAIBootcamp @GaibSpain @GlobalAIBC  https://urlzs.com/u8ZB 📢 En el otro lado del ring, en el Track 2 a las 14:45 "Mejorando el rendimiento de un servidor con Inteligencia Artificial" por otro de nuestros MVPs @enriquecatala y @pausempere  👏👏👏#GlobalAIBootcamp 2019 #Madrid. Mas info en  https://urlzs.com/u8ZB 📢 Después de la comida en el Track 1 a las 14:45 "R y Python con Power BI, la ciencia y el análisis de datos, juntos” por otro MVP!!!! @ambynet 👏👏👏 #GlobalAIBootcamp 2019 #Madrid Mas info \uf0e8  https://urlzs.com/u8ZB ¿Qué piensan nuestros políticos? AI for Twitter. #GlobalAIBootcamp @ericmcmc1  https://urlzs.com/u8ZB #GlobalAIBootcamp @GaibSpain  https://urlzs.com/u8ZB #GlobalAIBootcamp #Madrid #DataPla…. RT @rfcm83: RT ambynet: Modelado, modelado y modelado para MSPowerBI #DataCleansing #DAX #DataMining #QnA #Bot #GlobalAIBootcamp  KabelSist…. RT @sara_sanluis: ¿En qué piensan nuestros políticos?🤔 @ericmcmc1 y Miguel nos cuentan cómo descubrirlo usando NLP en el #GlobalAIBootcamp.…. RT @JaimeAbad9: Hoy estoy en el Gobal AI Community en @MicrosoftES #GlobalAIBootcamp  https://urlzs.com/u8ZB #Pipeline #GlobalAIBootcamp  https://urlzs.com/u8ZB #GlobalAIBootcamp al #everisLivingLab. Un evento mundial en el que distintas comunidades se unen para compartir conocimie…. RT @calelltek: Adelantando herramientas de trabajo #AzureDevOps #GlobalAIBootcamp  https://urlzs.com/u8ZB ón #CoralDevBoard #GlobalAIBootcamp  https://urlzs.com/u8ZB 📸 Nuestros compañeros @miguelEgea , @pausempere y @enriquecatala , speakers en el #GlobalAIbootcamp 2019 de #Madrid :) @GaibS…. RT @ambynet: Me ha gustado mucho la charla y las demos presentadas por @carloscalvo_es en #GlobalAIBootcamp #Madrid @MicrosoftES #R #Machin…. RT @RechOneSix: Politweets con @ericmcmc1 y Miguel Saenz #GlobalAIBootcamp @GaibSpain  https://urlzs.com/u8ZB #DataCleansing #DAX #DataMining #QnA #Bot #GlobalAIBootcamp  Kabel…. Cuartas sesiones del día en el #GlobalAIBootcamp. Lo q os estáis perdiendo!!!!  https://urlzs.com/u8ZB #globalaibootcamp online  https://urlzs.com/u8ZB 📢 En el otro lado del ring en el Track 2 a las 13:00 "AI de serie en la Power Platform" por otro de nuestros MVPs @tgranell 👏👏👏#GlobalAIBootcamp 2019 #Madrid entérate como viene de cargada de inteligencia la Microsoft Power Platform Mas info en  https://urlzs.com/u8ZB 📢 Nuevamente en el Track 1 a las 13:00  "Politweets – AI para saber que piensan nuestros políticos” por @ericmcmc1 y @Miguel Saenz 👏👏👏 #GlobalAIBootcamp 2019 #Madrid un tema muy de moda!!!! 😉 Mas info \uf0e8  https://urlzs.com/u8ZB #GlobalAIBootcamp GaibSpain plainconcepts #AI  https://urlzs.com/u8ZB …. RT @alejandrolmeida: No te pierdas la emisión en directo del #GlobalAIBootcamp de #Madrid!  https://urlzs.com/u8ZB #DevOps #IoTEdge #GlobalAIBootcamp  @GaibSpain @alexndrglez  https://urlzs.com/u8ZB #GlobalAIBootcamp. Qué nivel de charla 🙌🤓  https://urlzs.com/u ...

# %%
import markovify

markov_model = markovify.Text(processed_tweets_text)

# %%
num_phishing_tweets_desired = 5
num_phishing_tweets_so_far = 0
generated_tweets = []
while num_phishing_tweets_so_far < num_phishing_tweets_desired:
    tweet = markov_model.make_short_sentence(140)
    if phishing_link in tweet and tweet not in generated_tweets:
        generated_tweets.append(tweet)
        num_phishing_tweets_so_far += 1

# %%
for tweet in generated_tweets:
    print(tweet)
# Out:
# Good luck mate!!! 👍👍👍 https://urlzs.com/u8ZB #Politweets #GlobalAIBootcamp https://urlzs.com/u8ZB #GlobalAIBootcamp #Madrid @GaibSpain?
# https://urlzs.com/u8ZB #DevOps #IoTEdge #GlobalAIBootcamp @GaibSpain https://urlzs.com/u8ZB #GlobalAIBootcamp.
# 👏👏👏👏#AI #ML #Azure https://urlzs.com/u8ZB #GlobalAIBootcamp @GaibSpain https://urlzs.com/u8ZB és del café....
# 👏👏👏👏#AI #ML #Azure https://urlzs.com/u8ZB #GlobalAIBootcamp https://urlzs.com/u8ZB #GlobalAIBootcamp al #everisLivingLab.
# 👍👍👍 @GaibSpain https://urlzs.com/u8ZB #GlobalAIBootcamp #Madrid @GaibSpain?

# %%
user = api.get_user(user_id)
for friend in user.friends():
    print(friend.screen_name)
# Out:
# sanketmraut
# angelus_gi
# azurebrains
# azureadvocates
# techtalkcorner
# hboelman
# PakoRho
# LiaRadovic
# oriolpuigbuil
# InsightIberia
# esterdenicolas
# rubenr79
# gontejjav
# _unaizc_
# magicheron
# luiselopezlopez
# tx_bals
# Belmontesh
# robtejero
# angelrubenyui
